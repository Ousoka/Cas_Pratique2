# %% [markdown]
# # Nom et Prénoms ici
# Ousmane KA

# %% [markdown]
# **Exercice 1 : (15 points)**

# %%
#NB: colonne des sexes
#Nombre de garcons et de fille d'une classe

# %% [markdown]
# L'objectif de cet exercice est de mettre en place un système d'aide à la délibération.

# %% [markdown]
# Le fichier **examens.xlsx** contient les notes des étudiants.

# %% [markdown]
# Le tableau suivant présente les coefficients des différents EC qui sont regroupés respectivement en UE **Physique**, **Mathématiques**, **Chimie**, **Informatique**, **OutilsBase** et **Graphique**

# %% [markdown]
# | EC        | Phy1 | Phy2 | TPPhy | Math1 | Math2 | Chimie1 | Chimie2 | TPChimie | Info1 | Info2 | Base1 | Base2 | Base3 | Gr1 | Gr2 |
# |---------------|------|------|-------|--------|-------|---------|---------|----------|-------|-------|-------|-------|-------|--------|---------|
# | Coefs  |  2.5 |  2.5 |   1   |   2.5  |  2.5  |   2.5   |   2.5   |     1    |  2.5  |  2.5  |  1.5  |  1.5  |   1   |    2   |    2    |

# %% [markdown]
# 1.  Écrire un programme qui permet de transformer le fichier **examens.xlsx** en Data Frame.

# %%
import os
import pandas as pd
import numpy as np
cwd = os.getcwd()
print(cwd)
os.chdir("C:\\Users\\LENOVO\\Desktop\\Informatique\\07-04-2022\\Cas_pratique_2")
fichier = "examens.xlsx"
xl = pd.ExcelFile(fichier)
deliberation=xl.parse("Resultats")
deliberation
# Out:
# C:\Users\LENOVO\Desktop\Informatique\07-04-2022\Cas_pratique_2
#         Nom       Prénom  Physique 1  Physique 2  TP Physique   Maths 1  \
# 0    DIALLO     Ibrahima      18.100      14.300           13    13.600
# 1        BA   Souleymane      19.700      17.600           16    16.000
# 2      BEYE      Alioune       4.750       4.300           10     8.602
# 3     BIAYE      Babacar      15.200      10.600           16    15.100
# 4     BALDE      Mamadou       4.700       7.100           15    13.150
# 5    CAMARA  Khadidiatou      13.700      11.100           10    10.252
# 6     CISSE          Awa      16.500      15.600           13    16.450
# 7     CISSE      Ousmane      15.100       6.700           10    12.800
# 8    DIAGNE        Marie      17.250      14.700           15    16.900
# 9      DIAW         Omar       2.900       8.600           15    10.000
# 10   DIATTA      Justine       6.798      10.800           16     3.700
# 11   DIALLO       Moussa       0.000       0.000            0     1.900
# 12    DIEYE       Fallou       8.650       9.352           15     8.050
# 13     DIOP       Bachir       8.000      10.800           13     6.700
# 14     DIOP      Birahim      11.250      11.680           15    15.850
# 15     DIOP         Keba       9.800       9.000           13     9.400
# 16     DIAO      Mariama      12.700      17.000           16    19.000
# 17     FALL     Ibrahima      13.550      16.300           13    17.500
# 18     FAYE         Ngor      13.150      17.800           10    13.900
# 19     FAYE    Moustapha       0.000       0.000            0     0.000
# 20     KEBE     Maimouna      19.400      20.000           13    18.100
# 21       LY   Ouleymatou       2.400       5.600            0     4.900
# 22       LY       Ramata      16.900      12.800           16    18.550
# 23    MANGA       Eleine       3.400       3.300           16     8.800
# 24    MBAYE       Saliou       7.810      11.000           13     9.400
# 25    MBAYE          Mor       0.000       0.000            0     5.950
# 26  MBENGUE      Aminata      15.300      14.000           15    13.680
# 27   NDIAYE        Fatou       1.750       4.900           18     6.000
# 28   NDIAYE         Aziz      18.350      17.800           18    15.550
# 29   NDIAYE     Seynabou       0.000       0.000            0     1.900
# 30    NDOUR        Adama       5.000      13.400            0    13.450
# 31    NDOYE       Sophie      10.800       9.800           18    10.450
# 32    NIANG        Tahir       0.000       0.000            0     0.000
# 33     SARR        Abdou       0.000       0.000            0     1.900
# 34     SECK        Badou      16.000      14.900           18    13.600
# 35     SECK     Mouhamed      12.000      19.000           18     7.450
# 36     SENE       Doudou      14.800       7.300           15     9.550
# 37  SENGHOR     Mbagnick      16.400       4.200           11    10.600
# 38       SY     Cheikhou       0.000       0.000            0     0.000
# 39     SOW     Fatoumata       0.000       0.000            0     4.400
# 40     SOW           Ady      12.000       8.000           14    13.000
# 41     TAYE         Issa      15.000      10.000           16    11.000
# 42  THIOUNE      Ismaila      10.000      15.200           15    11.350
# 43    TOURE    Ndeye Amy      16.300      13.700           20    13.150
#
#      Maths 2  Chimie 1  Chimie 2  TP Chimie  Info 1  Info 2  Base 1  Base 2  \
# 0     15.800      14.0      11.5      16.00    16.0    15.2   14.40      10
# 1     19.000      16.6      16.8       0.00    20.0    20.0   16.00      12
# 2     11.400       5.4       8.4       6.00     2.8     6.1    8.40       7
# 3     15.000      18.6       8.2       8.00    15.8    14.8   14.40      11
# 4     16.000      10.6      11.0      16.00     7.2    14.9   13.40       8
# 5      9.752       9.4      12.9      20.00     8.8     7.6   11.60       7
# 6     14.600      15.8      10.3       6.00    17.0    16.1   14.80      10
# 7     13.400      12.6       8.7      19.00     9.6    10.4   14.80       8
# 8     16.900      13.0      16.1      14.00    19.0    17.4    9.00       7
# 9     16.400      14.4      11.3      12.00     8.6    18.6   13.56      10
# 10     8.600      11.0       5.4      19.00     3.6     6.0    6.60      12
# 11     0.000       0.0       0.0       0.00     0.0     0.0    0.00       0
# 12    11.940       9.8       8.0      19.00    14.8    12.1   11.60       7
# 13     7.800      11.2       9.1       9.25    11.2    12.6   16.00      10
# 14    17.300      15.2      10.0      14.00    16.4    12.1   15.00      11
# 15    17.000      11.8      11.8       0.00    15.2    14.0   15.40      10
# 16    18.100      17.6      17.6      19.00    16.4    20.0   15.00      10
# 17    17.200      12.8      12.7      14.00    10.2    17.9   14.40      13
# 18    15.800      15.8      11.3      14.00    12.4    17.0   13.40       7
# 19     0.000       0.0       0.0       0.00     0.0     0.0    0.00       0
# 20    18.400      16.4      16.7      18.00    18.2    18.6   14.44      14
# 21     5.200       4.4       1.6       0.00     2.8     4.4    7.00       0
# 22    17.500      18.2      16.1      20.00    20.0    19.1   16.20      13
# 23    13.700      10.8       6.6      19.00    11.6    10.2    7.20      11
# 24    11.200       9.6      10.3      19.00    11.8    14.5    7.80      10
# 25     4.200      11.2       5.4       0.00     2.0     2.4    0.00       0
# 26    14.600      14.8       6.2      19.00    17.4    12.6   14.80       9
# 27    10.600       9.4       4.9      16.00     6.4     5.6   11.60      10
# 28    15.600      15.8      13.9      20.00    20.0    19.7   14.24      10
# 29     0.000       0.0       0.0       0.00     0.0     0.0    0.00       0
# 30    13.100      14.2       3.9       0.00     3.6     3.9   16.00      10
# 31     9.550       9.8       9.2      20.00    10.0    15.0   12.20      12
# 32     0.000       0.0       0.0       0.00     0.0     0.0    0.00       0
# 33     0.000       0.0       0.0       0.00     0.0     0.0    0.00       0
# 34    11.500      11.8      12.7      16.00    14.4    15.7    6.60      11
# 35    14.100      15.8      11.6       6.00    16.0    17.4   15.20       8
# 36    14.200      13.4       9.7      20.00    12.8    11.8   15.40      11
# 37    11.000      15.0       8.6       8.00    15.8    14.1   14.40       9
# 38     0.000       0.0       0.0       0.00     0.0     0.0    0.00       0
# 39     3.600       4.0       2.8       0.00     2.0     3.6    0.00       0
# 40    17.000      10.0       7.0       9.00    12.0     8.0    6.00       4
# 41     9.000      16.0      15.0      18.00    14.0    12.0    9.00      10
# 42    13.400      16.2      13.6      20.00    12.2    13.6   12.00       8
# 43    18.800      14.2       7.6      12.00    14.0    19.1   14.00      11
#
#     Base 3  Graphique 1  Graphique 2
# 0       17         10.4           10
# 1       16         15.6           18
# 2       11         15.6           11
# 3       13          9.4           14
# 4       12         14.8           15
# 5       15          8.2            7
# 6       12         13.6           10
# 7       14          4.8           12
# 8       17         12.2           17
# 9       15         13.4           15
# 10      14         10.8           14
# 11       0          0.0            0
# 12      17         13.0           15
# 13      16         11.0           12
# 14      18         11.6           10
# 15      15         11.4           13
# 16      14         14.0           13
# 17      13         13.6           16
# 18      14         12.6           14
# 19       0          0.0            0
# 20      17         16.2           17
# 21       0          0.0            0
# 22      18         14.4           14
# 23      16         11.0           12
# 24      17         17.4           17
# 25       0          5.4            0
# 26      13         13.8           13
# 27      16         14.0           12
# 28      15         12.2           17
# 29       0          0.0            0
# 30      12         14.0            6
# 31      16         12.2           16
# 32       0          0.0            0
# 33       0          0.0            0
# 34      15         13.6            9
# 35      17         13.4            7
# 36      15         11.4           10
# 37      12         12.6           10
# 38       0          0.0            0
# 39       0          0.0            0
# 40       7          9.0            8
# 41      16         13.0           12
# 42      14         15.4           14
# 43      12         12.6           13

# %% [markdown]
# 2. En se basant sur le tableau des coefficients, écrire un programme qui cacule la moyenne de chaque UE et détermine si l'étudiant l'a validée ou pas.

# %%
P1= deliberation.iloc[:, 2]*(2.5/6)
P2= deliberation.iloc[:, 3]*(2.5/6)
TPP= deliberation.iloc[:, 4]*(1/6)
P=P1+P2+TPP
#print(P)

M1= deliberation.iloc[:, 5]*(2.5/5)
M2= deliberation.iloc[:, 6]*(2.5/5)
M=M1+M2
#print(M)

C1= deliberation.iloc[:, 7]*(2.5/6)
C2= deliberation.iloc[:, 8]*(2.5/6)
TPC= deliberation.iloc[:, 9]*(1/6)
C=C1+C2+TPC
#print(C)

I1= deliberation.iloc[:, 10]*(2.5/5)
I2= deliberation.iloc[:, 11]*(2.5/5)
I=I1+I2
#print(I)

B1= deliberation.iloc[:, 12]*(1.5/4)
B2= deliberation.iloc[:, 13]*(1.5/4)
B3= deliberation.iloc[:, 14]*(1/4)
B=B1+B2+B3
#print(B)

G1= deliberation.iloc[:, 15]*(2/4)
G2= deliberation.iloc[:, 16]*(2/4)
G=G1+G2
#print(G)

# %%
deliberation1 = deliberation.iloc[:, 0:2]
deliberation1.insert(2, 'Physique', P, allow_duplicates = False)
deliberation1.insert(3, 'Maths', M, allow_duplicates = False)
deliberation1.insert(4, 'Chimie', C, allow_duplicates = False)
deliberation1.insert(5, 'Informatique', I, allow_duplicates = False)
deliberation1.insert(6, 'Base', B, allow_duplicates = False)
deliberation1.insert(7, 'Graphique', G, allow_duplicates = False)
deliberation1
# Out:
#         Nom       Prénom   Physique   Maths     Chimie  Informatique    Base  \
# 0    DIALLO     Ibrahima  15.666667  14.700  13.291667         15.60  13.400
# 1        BA   Souleymane  18.208333  17.500  13.916667         20.00  14.500
# 2      BEYE      Alioune   5.437500  10.001   6.750000          4.45   8.525
# 3     BIAYE      Babacar  13.416667  15.050  12.500000         15.30  12.775
# 4     BALDE      Mamadou   7.416667  14.575  11.666667         11.05  11.025
# 5    CAMARA  Khadidiatou  12.000000  10.002  12.625000          8.20  10.725
# 6     CISSE          Awa  15.541667  15.525  11.875000         16.55  12.300
# 7     CISSE      Ousmane  10.750000  13.100  12.041667         10.00  12.050
# 8    DIAGNE        Marie  15.812500  16.900  14.458333         18.20  10.250
# 9      DIAW         Omar   7.291667  13.200  12.708333         13.60  12.585
# 10   DIATTA      Justine   9.999167   6.150  10.000000          4.80  10.475
# 11   DIALLO       Moussa   0.000000   0.950   0.000000          0.00   0.000
# 12    DIEYE       Fallou  10.000833   9.995  10.583333         13.45  11.225
# 13     DIOP       Bachir  10.000000   7.250  10.000000         11.90  13.750
# 14     DIOP      Birahim  12.054167  16.575  12.833333         14.25  14.250
# 15     DIOP         Keba  10.000000  13.200   9.833333         14.60  13.275
# 16     DIAO      Mariama  15.041667  18.550  17.833333         18.20  12.875
# 17     FALL     Ibrahima  14.604167  17.350  12.958333         14.05  13.525
# 18     FAYE         Ngor  14.562500  14.850  13.625000         14.70  11.150
# 19     FAYE    Moustapha   0.000000   0.000   0.000000          0.00   0.000
# 20     KEBE     Maimouna  18.583333  18.250  16.791667         18.40  14.915
# 21       LY   Ouleymatou   3.333333   5.050   2.500000          3.60   2.625
# 22       LY       Ramata  15.041667  18.025  17.625000         19.55  15.450
# 23    MANGA       Eleine   5.458333  11.250  10.416667         10.90  10.825
# 24    MBAYE       Saliou  10.004167  10.300  11.458333         13.15  10.925
# 25    MBAYE          Mor   0.000000   5.075   6.916667          2.20   0.000
# 26  MBENGUE      Aminata  14.708333  14.140  11.916667         15.00  12.175
# 27   NDIAYE        Fatou   5.770833   8.300   8.625000          6.00  12.100
# 28   NDIAYE         Aziz  18.062500  15.575  15.708333         19.85  12.840
# 29   NDIAYE     Seynabou   0.000000   0.950   0.000000          0.00   0.000
# 30    NDOUR        Adama   7.666667  13.275   7.541667          3.75  12.750
# 31    NDOYE       Sophie  11.583333  10.000  11.250000         12.50  13.075
# 32    NIANG        Tahir   0.000000   0.000   0.000000          0.00   0.000
# 33     SARR        Abdou   0.000000   0.950   0.000000          0.00   0.000
# 34     SECK        Badou  15.875000  12.550  12.875000         15.05  10.350
# 35     SECK     Mouhamed  15.916667  10.775  12.416667         16.70  12.950
# 36     SENE       Doudou  11.708333  11.875  12.958333         12.30  13.650
# 37  SENGHOR     Mbagnick  10.416667  10.800  11.166667         14.95  11.775
# 38       SY     Cheikhou   0.000000   0.000   0.000000          0.00   0.000
# 39     SOW     Fatoumata   0.000000   4.000   2.833333          2.80   0.000
# 40     SOW           Ady  10.666667  15.000   8.583333         10.00   5.500
# 41     TAYE         Issa  13.083333  10.000  15.916667         13.00  11.125
# 42  THIOUNE      Ismaila  13.000000  12.375  15.750000         12.90  11.000
# 43    TOURE    Ndeye Amy  15.833333  15.975  11.083333         16.55  12.375
#
#     Graphique
# 0        10.2
# 1        16.8
# 2        13.3
# 3        11.7
# 4        14.9
# 5         7.6
# 6        11.8
# 7         8.4
# 8        14.6
# 9        14.2
# 10       12.4
# 11        0.0
# 12       14.0
# 13       11.5
# 14       10.8
# 15       12.2
# 16       13.5
# 17       14.8
# 18       13.3
# 19        0.0
# 20       16.6
# 21        0.0
# 22       14.2
# 23       11.5
# 24       17.2
# 25        2.7
# 26       13.4
# 27       13.0
# 28       14.6
# 29        0.0
# 30       10.0
# 31       14.1
# 32        0.0
# 33        0.0
# 34       11.3
# 35       10.2
# 36       10.7
# 37       11.3
# 38        0.0
# 39        0.0
# 40        8.5
# 41       12.5
# 42       14.7
# 43       12.8

# %%
DPk=[]
for i in range(len(P)):
    if P[i]>=10:
        DPk.append("Validé")
    else:
        DPk.append("Non Validé")
DMk=[]
for i in range(len(P)):
    if M[i]>=10:
        DMk.append("Validé")
    else:
        DMk.append("Non Validé")
DCk=[]
for i in range(len(P)):
    if C[i]>=10:
        DCk.append("Validé")
    else:
        DCk.append("Non Validé")
DIk=[]
for i in range(len(P)):
    if I[i]>=10:
        DIk.append("Validé")
    else:
        DIk.append("Non Validé")
DBk=[]
for i in range(len(P)):
    if B[i]>=10:
        DBk.append("Validé")
    else:
        DBk.append("Non Validé")
DGk=[]
for i in range(len(P)):
    if G[i]>=10:
        DGk.append("Validé")
    else:
        DGk.append("Non Validé")

# %%
deliberation3 = deliberation.iloc[:, 0:2]
deliberation3.insert(2, 'Physique', DPk, allow_duplicates = False)
deliberation3.insert(3, 'Maths', DMk, allow_duplicates = False)
deliberation3.insert(4, 'Chimie', DCk, allow_duplicates = False)
deliberation3.insert(5, 'Informatique', DIk, allow_duplicates = False)
deliberation3.insert(6, 'Base', DBk, allow_duplicates = False)
deliberation3.insert(7, 'Graphique', DGk, allow_duplicates = False)
deliberation3
# Out:
#         Nom       Prénom    Physique       Maths      Chimie Informatique  \
# 0    DIALLO     Ibrahima      Validé      Validé      Validé       Validé
# 1        BA   Souleymane      Validé      Validé      Validé       Validé
# 2      BEYE      Alioune  Non Validé      Validé  Non Validé   Non Validé
# 3     BIAYE      Babacar      Validé      Validé      Validé       Validé
# 4     BALDE      Mamadou  Non Validé      Validé      Validé       Validé
# 5    CAMARA  Khadidiatou      Validé      Validé      Validé   Non Validé
# 6     CISSE          Awa      Validé      Validé      Validé       Validé
# 7     CISSE      Ousmane      Validé      Validé      Validé       Validé
# 8    DIAGNE        Marie      Validé      Validé      Validé       Validé
# 9      DIAW         Omar  Non Validé      Validé      Validé       Validé
# 10   DIATTA      Justine  Non Validé  Non Validé      Validé   Non Validé
# 11   DIALLO       Moussa  Non Validé  Non Validé  Non Validé   Non Validé
# 12    DIEYE       Fallou      Validé  Non Validé      Validé       Validé
# 13     DIOP       Bachir      Validé  Non Validé      Validé       Validé
# 14     DIOP      Birahim      Validé      Validé      Validé       Validé
# 15     DIOP         Keba      Validé      Validé  Non Validé       Validé
# 16     DIAO      Mariama      Validé      Validé      Validé       Validé
# 17     FALL     Ibrahima      Validé      Validé      Validé       Validé
# 18     FAYE         Ngor      Validé      Validé      Validé       Validé
# 19     FAYE    Moustapha  Non Validé  Non Validé  Non Validé   Non Validé
# 20     KEBE     Maimouna      Validé      Validé      Validé       Validé
# 21       LY   Ouleymatou  Non Validé  Non Validé  Non Validé   Non Validé
# 22       LY       Ramata      Validé      Validé      Validé       Validé
# 23    MANGA       Eleine  Non Validé      Validé      Validé       Validé
# 24    MBAYE       Saliou      Validé      Validé      Validé       Validé
# 25    MBAYE          Mor  Non Validé  Non Validé  Non Validé   Non Validé
# 26  MBENGUE      Aminata      Validé      Validé      Validé       Validé
# 27   NDIAYE        Fatou  Non Validé  Non Validé  Non Validé   Non Validé
# 28   NDIAYE         Aziz      Validé      Validé      Validé       Validé
# 29   NDIAYE     Seynabou  Non Validé  Non Validé  Non Validé   Non Validé
# 30    NDOUR        Adama  Non Validé      Validé  Non Validé   Non Validé
# 31    NDOYE       Sophie      Validé      Validé      Validé       Validé
# 32    NIANG        Tahir  Non Validé  Non Validé  Non Validé   Non Validé
# 33     SARR        Abdou  Non Validé  Non Validé  Non Validé   Non Validé
# 34     SECK        Badou      Validé      Validé      Validé       Validé
# 35     SECK     Mouhamed      Validé      Validé      Validé       Validé
# 36     SENE       Doudou      Validé      Validé      Validé       Validé
# 37  SENGHOR     Mbagnick      Validé      Validé      Validé       Validé
# 38       SY     Cheikhou  Non Validé  Non Validé  Non Validé   Non Validé
# 39     SOW     Fatoumata  Non Validé  Non Validé  Non Validé   Non Validé
# 40     SOW           Ady      Validé      Validé  Non Validé       Validé
# 41     TAYE         Issa      Validé      Validé      Validé       Validé
# 42  THIOUNE      Ismaila      Validé      Validé      Validé       Validé
# 43    TOURE    Ndeye Amy      Validé      Validé      Validé       Validé
#
#           Base   Graphique
# 0       Validé      Validé
# 1       Validé      Validé
# 2   Non Validé      Validé
# 3       Validé      Validé
# 4       Validé      Validé
# 5       Validé  Non Validé
# 6       Validé      Validé
# 7       Validé  Non Validé
# 8       Validé      Validé
# 9       Validé      Validé
# 10      Validé      Validé
# 11  Non Validé  Non Validé
# 12      Validé      Validé
# 13      Validé      Validé
# 14      Validé      Validé
# 15      Validé      Validé
# 16      Validé      Validé
# 17      Validé      Validé
# 18      Validé      Validé
# 19  Non Validé  Non Validé
# 20      Validé      Validé
# 21  Non Validé  Non Validé
# 22      Validé      Validé
# 23      Validé      Validé
# 24      Validé      Validé
# 25  Non Validé  Non Validé
# 26      Validé      Validé
# 27      Validé      Validé
# 28      Validé      Validé
# 29  Non Validé  Non Validé
# 30      Validé      Validé
# 31      Validé      Validé
# 32  Non Validé  Non Validé
# 33  Non Validé  Non Validé
# 34      Validé      Validé
# 35      Validé      Validé
# 36      Validé      Validé
# 37      Validé      Validé
# 38  Non Validé  Non Validé
# 39  Non Validé  Non Validé
# 40  Non Validé  Non Validé
# 41      Validé      Validé
# 42      Validé      Validé
# 43      Validé      Validé

# %% [markdown]
# 3. Écrire un programme qui insère une colonne de validation (**V** : UE validée, **NV** : UE non validée) après chaque UE.

# %%
DP=[]
for i in range(len(P)):
    if P[i]>=10:
        DP.append("V")
    else:
        DP.append("NV")
DM=[]
for i in range(len(P)):
    if M[i]>=10:
        DM.append("V")
    else:
        DM.append("NV")
DC=[]
for i in range(len(P)):
    if C[i]>=10:
        DC.append("V")
    else:
        DC.append("NV")
DI=[]
for i in range(len(P)):
    if I[i]>=10:
        DI.append("V")
    else:
        DI.append("NV")
DB=[]
for i in range(len(P)):
    if B[i]>=10:
        DB.append("V")
    else:
        DB.append("NV")
DG=[]
for i in range(len(P)):
    if G[i]>=10:
        DG.append("V")
    else:
        DG.append("NV")

# %%
deliberation2 = deliberation.iloc[:, 0:2]
deliberation2.insert(2, 'Physique', DP, allow_duplicates = False)
deliberation2.insert(3, 'Maths', DM, allow_duplicates = False)
deliberation2.insert(4, 'Chimie', DC, allow_duplicates = False)
deliberation2.insert(5, 'Informatique', DI, allow_duplicates = False)
deliberation2.insert(6, 'Base', DB, allow_duplicates = False)
deliberation2.insert(7, 'Graphique', DG, allow_duplicates = False)
deliberation2
# Out:
#         Nom       Prénom Physique Maths Chimie Informatique Base Graphique
# 0    DIALLO     Ibrahima        V     V      V            V    V         V
# 1        BA   Souleymane        V     V      V            V    V         V
# 2      BEYE      Alioune       NV     V     NV           NV   NV         V
# 3     BIAYE      Babacar        V     V      V            V    V         V
# 4     BALDE      Mamadou       NV     V      V            V    V         V
# 5    CAMARA  Khadidiatou        V     V      V           NV    V        NV
# 6     CISSE          Awa        V     V      V            V    V         V
# 7     CISSE      Ousmane        V     V      V            V    V        NV
# 8    DIAGNE        Marie        V     V      V            V    V         V
# 9      DIAW         Omar       NV     V      V            V    V         V
# 10   DIATTA      Justine       NV    NV      V           NV    V         V
# 11   DIALLO       Moussa       NV    NV     NV           NV   NV        NV
# 12    DIEYE       Fallou        V    NV      V            V    V         V
# 13     DIOP       Bachir        V    NV      V            V    V         V
# 14     DIOP      Birahim        V     V      V            V    V         V
# 15     DIOP         Keba        V     V     NV            V    V         V
# 16     DIAO      Mariama        V     V      V            V    V         V
# 17     FALL     Ibrahima        V     V      V            V    V         V
# 18     FAYE         Ngor        V     V      V            V    V         V
# 19     FAYE    Moustapha       NV    NV     NV           NV   NV        NV
# 20     KEBE     Maimouna        V     V      V            V    V         V
# 21       LY   Ouleymatou       NV    NV     NV           NV   NV        NV
# 22       LY       Ramata        V     V      V            V    V         V
# 23    MANGA       Eleine       NV     V      V            V    V         V
# 24    MBAYE       Saliou        V     V      V            V    V         V
# 25    MBAYE          Mor       NV    NV     NV           NV   NV        NV
# 26  MBENGUE      Aminata        V     V      V            V    V         V
# 27   NDIAYE        Fatou       NV    NV     NV           NV    V         V
# 28   NDIAYE         Aziz        V     V      V            V    V         V
# 29   NDIAYE     Seynabou       NV    NV     NV           NV   NV        NV
# 30    NDOUR        Adama       NV     V     NV           NV    V         V
# 31    NDOYE       Sophie        V     V      V            V    V         V
# 32    NIANG        Tahir       NV    NV     NV           NV   NV        NV
# 33     SARR        Abdou       NV    NV     NV           NV   NV        NV
# 34     SECK        Badou        V     V      V            V    V         V
# 35     SECK     Mouhamed        V     V      V            V    V         V
# 36     SENE       Doudou        V     V      V            V    V         V
# 37  SENGHOR     Mbagnick        V     V      V            V    V         V
# 38       SY     Cheikhou       NV    NV     NV           NV   NV        NV
# 39     SOW     Fatoumata       NV    NV     NV           NV   NV        NV
# 40     SOW           Ady        V     V     NV            V   NV        NV
# 41     TAYE         Issa        V     V      V            V    V         V
# 42  THIOUNE      Ismaila        V     V      V            V    V         V
# 43    TOURE    Ndeye Amy        V     V      V            V    V         V

# %% [markdown]
# 4. Écrire un programme qui trie les noms et prénoms par ordre alphabétique.

# %%
tri_deliberation2=deliberation2.sort_values(by=['Nom','Prénom'], ascending=[True,True])
tri_deliberation2
# Out:
#         Nom       Prénom Physique Maths Chimie Informatique Base Graphique
# 1        BA   Souleymane        V     V      V            V    V         V
# 4     BALDE      Mamadou       NV     V      V            V    V         V
# 2      BEYE      Alioune       NV     V     NV           NV   NV         V
# 3     BIAYE      Babacar        V     V      V            V    V         V
# 5    CAMARA  Khadidiatou        V     V      V           NV    V        NV
# 6     CISSE          Awa        V     V      V            V    V         V
# 7     CISSE      Ousmane        V     V      V            V    V        NV
# 8    DIAGNE        Marie        V     V      V            V    V         V
# 0    DIALLO     Ibrahima        V     V      V            V    V         V
# 11   DIALLO       Moussa       NV    NV     NV           NV   NV        NV
# 16     DIAO      Mariama        V     V      V            V    V         V
# 10   DIATTA      Justine       NV    NV      V           NV    V         V
# 9      DIAW         Omar       NV     V      V            V    V         V
# 12    DIEYE       Fallou        V    NV      V            V    V         V
# 13     DIOP       Bachir        V    NV      V            V    V         V
# 14     DIOP      Birahim        V     V      V            V    V         V
# 15     DIOP         Keba        V     V     NV            V    V         V
# 17     FALL     Ibrahima        V     V      V            V    V         V
# 19     FAYE    Moustapha       NV    NV     NV           NV   NV        NV
# 18     FAYE         Ngor        V     V      V            V    V         V
# 20     KEBE     Maimouna        V     V      V            V    V         V
# 21       LY   Ouleymatou       NV    NV     NV           NV   NV        NV
# 22       LY       Ramata        V     V      V            V    V         V
# 23    MANGA       Eleine       NV     V      V            V    V         V
# 25    MBAYE          Mor       NV    NV     NV           NV   NV        NV
# 24    MBAYE       Saliou        V     V      V            V    V         V
# 26  MBENGUE      Aminata        V     V      V            V    V         V
# 28   NDIAYE         Aziz        V     V      V            V    V         V
# 27   NDIAYE        Fatou       NV    NV     NV           NV    V         V
# 29   NDIAYE     Seynabou       NV    NV     NV           NV   NV        NV
# 30    NDOUR        Adama       NV     V     NV           NV    V         V
# 31    NDOYE       Sophie        V     V      V            V    V         V
# 32    NIANG        Tahir       NV    NV     NV           NV   NV        NV
# 33     SARR        Abdou       NV    NV     NV           NV   NV        NV
# 34     SECK        Badou        V     V      V            V    V         V
# 35     SECK     Mouhamed        V     V      V            V    V         V
# 36     SENE       Doudou        V     V      V            V    V         V
# 37  SENGHOR     Mbagnick        V     V      V            V    V         V
# 40     SOW           Ady        V     V     NV            V   NV        NV
# 39     SOW     Fatoumata       NV    NV     NV           NV   NV        NV
# 38       SY     Cheikhou       NV    NV     NV           NV   NV        NV
# 41     TAYE         Issa        V     V      V            V    V         V
# 42  THIOUNE      Ismaila        V     V      V            V    V         V
# 43    TOURE    Ndeye Amy        V     V      V            V    V         V

# %% [markdown]
# 5. Écrire un programme qui enregistre dans un nouveau fichier excel les résultats obtenus.

# %%
OK=pd.ExcelWriter("Délibération.xlsx",engine="xlsxwriter")
tri_deliberation2.to_excel(OK, "Délibération",index=False)
OK.save()

# %% [markdown]
# 6. Écrire un programme qui détermine le major de la classe. Les crédits des UE sont respectivement 12, 10, 12, 10, 8 et 8.

# %%
#Les credits representent en quelque sorte le poids de chaque UE at ainsi peuvent servir de coefficients pour le calcul de la moyenne
#Calcul de la moyenne de chaque étudiant
M=((P*12)+(M*10)+(C*12)+(I*10)+(B*8)+(G*8))/(12+10+12+10+8+8)
deliberation4 = deliberation.iloc[:, 0:2]
deliberation4.insert(2, 'Moyenne', M, allow_duplicates = False)
tri_deliberation2=deliberation4.sort_values(by=['Moyenne'], ascending=[False])
tri_deliberation2
# Out:
#         Nom       Prénom    Moyenne
# 20     KEBE     Maimouna  17.241222
# 1        BA   Souleymane  16.739722
# 22       LY       Ramata  16.536528
# 28   NDIAYE         Aziz  16.440667
# 16     DIAO      Mariama  15.827778
# 8    DIAGNE        Marie  14.937083
# 17     FALL     Ibrahima  14.051250
# 0    DIALLO     Ibrahima  13.869722
# 43    TOURE    Ndeye Amy  13.858472
# 6     CISSE          Awa  13.795417
# 35     SECK     Mouhamed  13.758750
# 18     FAYE         Ngor  13.651250
# 42  THIOUNE      Ismaila  13.558194
# 26  MBENGUE      Aminata  13.500278
# 34     SECK        Badou  13.351111
# 3     BIAYE      Babacar  13.247500
# 41     TAYE         Issa  13.247222
# 14     DIOP      Birahim  12.935000
# 36     SENE       Doudou  12.264861
# 31    NDOYE       Sophie  12.263333
# 24    MBAYE       Saliou  12.225972
# 9      DIAW         Omar  11.844333
# 37  SENGHOR     Mbagnick  11.832500
# 15     DIOP         Keba  11.796111
# 12    DIEYE       Fallou  11.619778
# 13     DIOP       Bachir  11.109722
# 4     BALDE      Mamadou  11.039028
# 7     CISSE      Ousmane  10.807500
# 5    CAMARA  Khadidiatou  10.468667
# 23    MANGA       Eleine   9.608889
# 10   DIATTA      Justine   9.328972
# 40     SOW           Ady   9.030556
# 27   NDIAYE        Fatou   8.660694
# 30    NDOUR        Adama   8.185417
# 2      BEYE      Alioune   7.381833
# 21       LY   Ouleymatou   2.609722
# 25    MBAYE          Mor   2.602639
# 39     SOW     Fatoumata   1.316667
# 33     SARR        Abdou   0.026389
# 11   DIALLO       Moussa   0.026389
# 29   NDIAYE     Seynabou   0.026389
# 32    NIANG        Tahir   0.000000
# 19     FAYE    Moustapha   0.000000
# 38       SY     Cheikhou   0.000000

# %%
print("Le mayor de la classe est donc Maimouna Kebe.")
#A revoir
# KO=ntri_deliberation2.loc[:,0]
# print(KO)
# Out:
# Le mayor de la classe est donc Maimouna Kebe.

# %% [markdown]
# 7. Écrire un programme qui détermine pour chaque UE, le nombre d'étudiants validés. Les résultats obtenus seront rangés dans une liste.

# %%
df1=deliberation1.loc[deliberation1.loc[:, 'Physique']>=10]
df2=deliberation1.loc[deliberation1.loc[:, 'Maths']>=10]
df3=deliberation1.loc[deliberation1.loc[:, 'Chimie']>=10]
df4=deliberation1.loc[deliberation1.loc[:, 'Informatique']>=10]
df5=deliberation1.loc[deliberation1.loc[:, 'Base']>=10]
df6=deliberation1.loc[deliberation1.loc[:, 'Graphique']>=10]
a1,b1=df1.shape
a2,b2=df2.shape
a3,b3=df3.shape
a4,b4=df4.shape
a5,b5=df5.shape
a6,b6=df6.shape
print("En Physique,",a1,"étudiants ont validés")
print("En Maths,",a2,"étudiants ont validés")
print("En Chimie,",a3,"étudiants ont validés")
print("En Informatique,",a4,"étudiants ont validés")
print("En Base,",a5,"étudiants ont validés")
print("En Graphique,",a6,"étudiants ont validés")
# Out:
# En Physique, 28 étudiants ont validés
# En Maths, 31 étudiants ont validés
# En Chimie, 30 étudiants ont validés
# En Informatique, 30 étudiants ont validés
# En Base, 33 étudiants ont validés
# En Graphique, 32 étudiants ont validés

# %% [markdown]
# 8. Tracer la courbe des UE validées.

# %%
x=['Physique','Maths','Chimie','Informatique','Base','Graphique']
y=[a1,a2,a3,a4,a5,a6]
import matplotlib.pyplot as plt
fig=plt.figure()
plt.plot(x,y)
#****************Q9***************************
plt.savefig('UE_Validées.png')
#****************Q9***************************
plt.show()

# %% [markdown]
# 9. Écrire un programme qui insère la courbe (question 8) dans le fichier de la question 5 dans une nouvelle feuille.

# %%
import openpyxl
wb = openpyxl.load_workbook('Deliberation.xlsx')
wb.create_sheet('Courbe')
ws = wb['Courbe']
img = openpyxl.drawing.image.Image('UE_Validées.png')
img.anchor = 'A1'
ws.add_image(img)
wb.save('Deliberation1.xlsx')

# %% [markdown]
# # **BROUILLON**

# %% [markdown]
# **Exercice 2 :**

# %% [markdown]
# Le tableau ci-dessous illustre la croissance de la production en pourcentage dans différentes régions mondiales.

# %% [markdown]
# | Régions mondiales                             | 2000-2007 |   2008   |  2009   |  2010  |  2011  |
# |-----------------------------------------------|-----------|----------|---------|--------|--------|
# | Economie mondiale %                           |    3.2    |   1.5    |  -2.2   |   4.1  |   2.8  |
# | Economies développées %                       |    2.6    |   0.1    |  -3.2   |   3    |   1.6  |
# | Pays émergents et pays <br>en développement % |    6.5    |   6.1    |   2.7   |   7.4  |   6.2  |

# %% [markdown]
# 1. Tracer toutes les courbes en fonction des années sur la même figure.

# %% [markdown]
# 2. Tracer les différents diagrammes en bar de ce tableau.

# %%
#question_1

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
annee=["2000-2007","2008","2009","2010","2011"]
Economie_mondiale = [3.2,1.5,-2.2,4.1,2.8]
Economies_developpees =[2.6,0.1,-3.2,3,1.6]
Pays_emergents_et_pays_en_developpement=[6.5,6.1,2.7,7.4,6.2]
plt.plot(annee,Economie_mondiale,label="Economie mondiale %	")
plt.plot(annee,Economies_developpees,label="Economies développées %	")
plt.plot(annee,Pays_emergents_et_pays_en_developpement,label="Pays émergents et pays en développement %")
plt.legend()
plt.show()

# %%
#question_2

#1er diagramme
largeur=0.5
plt.bar(annee,Economie_mondiale,largeur, label="Economie mondiale %")
plt.legend()
plt.show()

#2eme diagramme
plt.bar(annee,Economies_developpees,largeur,label="Economies développées %	")
plt.legend()
plt.show()

#3eme diagramme
plt.bar(annee,Pays_emergents_et_pays_en_developpement,largeur, label="Pays émergents et pays en développement %")
plt.legend()
plt.show()

# %% [markdown]
# # FIN
